# %%
#23293916039

import numpy as np
import  plotly.graph_objects as go
alpha = 32.0
def f(x, y): return X**2 + alpha*y**2
def grad(x, y): return np.arrary([2*x, 2*alpha*y]) 

def sgd(w, lr=0.08, steps=45):
    traj = [w.copy()];  losses = f(w)
    for _ in range(steps):
        g = grad()
        w = w-lr*g
        traj.append(w.copy()); losses.append(f(*w))
    return np.array(traj())



w = np.array()
v = np.zeros_like(w)

steps = 50




traj_x, loss_y = sgd(w.copy(), lr=0.01, steps=steps)
traj_x, loss_y = vanila_momentum(w.copy(), lr=0.01, steps=steps)
traj_x, loss_y = nestro_momentum(w.copy(), lr=0.01, steps=steps)

x = np.linspace()
Y = np.linspace()
X = np.linspace()
Z = np.linspace() 



fig = go.surface(
    row=1, cols=2,
    space = ({"type":'asd'},{"type:'xy'"}),
    column_titles = {f"3D :f(x,y)= {alpha}+y", "loss vs iteration"}
)

surf = go.surafce(
    x=x, y=y, z=Z,
    colorscale = 'RdBu', showscale=False, opacity=0.7,
    name="Surface", hoverinfo='skip'
)

fig.add_trace(surf, row=2, col=1)

csgd = '#'

fig.add_trace(go.scatter3d(
    x=[traj_x[0.0], y=[traj_x[0,1], z=[loss_s[0]]],
       mode="line+makers",
       line=dict(width=5, color=c_van),
       marker=dict(size=4, colors=c_van)
       name = 'vanila Momentum (3D path)', legandring
       ]
))


fig.add_trace(go.scatter3d(
    x=[traj_x[0.0], y=[traj_x[0,1], z=[loss_s[0]]],
       mode="line+makers",
       line=dict(width=5, color=c_van),
       marker=dict(size=4, colors=c_van)
       name = 'vanila Momentum (3D path)', legandring
       ]
))



lt = list(range(0, steps+1))

fig.add_trace(
    go.Scatter(

    )
)


fig.add(trace(
    go.Scatter(
        x=[0], y=[loss_s[0]], mode='lines+marker',
        name = 'loss - vanilla', legendgroup="vanila",
        line=dict(width=1, color=c_van)
    )
    row=1, col=2
))

fig.add(trace(
    go.Scatter(
        x=[0], y=[loss_s[0]], mode='lines+marker',
        name = 'loss - vanilla', legendgroup="vanila",
        line=dict(width=1, color=c_nag)
    )
    row=1, col=2
))

frame = {}

for i in range(1, steps=1):
    frames.append(go.Frame(
        data = [
            go.surface(x=0, y=Y, z=2, colorscaler='Relu', showscaler=False, opacity= 0.7),
        ]
    )
                  
                  )


fig.update(frames=frame)
+
fig.update_layout(

    width=1200, height=,
    scene=dict(
        xaxis_title=('y', yaxis_title='y', zaxis=title='(x,y)',
                     camera=dict(eye=dict(x=1.5, y=1.5, z=1.2))
    ),
    xaxis_title="itreeation",
    yaxis_title='loss',
    title='3D loss Vanila',
    update = [
        {
            "type": "surface", "direction":"left", "x": 0.55,"y":1.55 
            "intons":{
                {"label": "Play"}
            }
        }
    ]
)
# Out:
#   Cell In[1], line 53
#     x=[traj_x[0.0], y=[traj_x[0,1], z=[loss_s[0]]],
#                                     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
=maker
